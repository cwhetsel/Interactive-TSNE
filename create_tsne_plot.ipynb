# %%
from sklearn.manifold import TSNE
#from keras.datasets import mnist
from sklearn.datasets import load_iris
from numpy import reshape
import matplotlib.pyplot
import pickle
from matplotlib.pyplot import imshow
import seaborn as sns
import pandas as pd
import torch
import os

# %%
from InteractivePlot import PrepareData

# %%
model = '/Users/ashah/Desktop/Self-Supervised-Learner-main/SIMCLR_ssl12.ckpt'
data_path = "/Users/ashah/Desktop/Planet_3BVisual/marine_litter_order_03172020/files/Dataset/Unlabelled"

# %%
from InteractivePlot import InteractiveAllclose

# %%
t_sne_folder = "/Users/ashah/Desktop/Self-Supervised-Learner-main/t_sne_data"

# %%
with open('data.pickle', 'rb') as input:
    data = pickle.load(input)

#data = pickle.load(open("data.pickle", "rb", -1))

# %%
data.cl
# Out:
# array([13, 15, 16, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,  6,
#         5, 16, 14, 15, 17,  5, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        16, 16, 12, 16, 16, 16, 12, 13, 15, 15, 15, 15, 15,  5,  5, 16, 15,
#        16, 15, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16,  4, 16, 16, 16,
#        16, 16, 16, 16, 16, 16,  5, 12, 15, 15, 15, 15,  5,  4,  5, 16, 16,
#        15, 16,  8, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 15, 15, 15,
#        15, 15, 15, 15, 15, 13, 15, 15, 15, 15, 15, 15, 13, 12, 12, 15, 15,
#        15, 15, 13, 17, 13, 12,  4, 15, 16, 16, 16, 16, 16, 16,  1, 19,  8,
#         1,  1, 12,  1,  1,  1,  9,  5,  5,  5, 16, 16,  4, 15, 16, 16, 16,
#         4,  5, 16, 16, 16, 16,  5, 16, 16, 16,  8,  8,  5, 16, 16, 16, 16,
#        16, 15, 15, 15, 15, 16, 16, 16, 16, 15, 16, 15, 15, 15, 15, 15, 16,
#        16, 15, 16, 16, 16, 16, 16, 15,  5, 12, 16, 16, 16, 16, 16, 13, 16,
# ...

# %%
# %matplotlib notebook
p = InteractiveAllclose(data.cl, data.tsne_obj, data.objects, data.spd)
# Out:
# <img src="data:image/png;base64,..." width="1500">
