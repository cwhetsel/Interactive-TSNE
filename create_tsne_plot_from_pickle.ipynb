# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from sklearn.manifold import TSNE
#from keras.datasets import mnist
from sklearn.datasets import load_iris
from numpy import reshape
import matplotlib.pyplot
import pickle
from matplotlib.pyplot import imshow
import seaborn as sns
import pandas as pd
import torch
import os
import numpy
import InteractivePlot as iplot
from InteractivePlot import PrepareData

# %%
with open('data_cl.pickle', 'rb') as input:
    cl = pickle.load(input)
with open('data_objects.pickle', 'rb') as input:
    objects = pickle.load(input)
with open('data_tsne_obj.pickle', 'rb') as input:
    tsne_obj = pickle.load(input)
spd = numpy.load('spd.npy')
# Out:
# "\nfor i, filename in enumerate(data.objects['filename']):\n    if '/content/' in filename[0:9]:\n        data.objects['filename'][i] = filename[9:]\n    if 'marine_debris' in filename[-20:-1]:\n        data.objects['name'][i] = 'Debris'\n"

# %%
print(len(objects))
print(len(objects[objects['name'] == 'Debris']))
# Out:
# 23565
# 740

# %%
spd.shape
# Out:
# (23565, 23565)

# %%
# %matplotlib notebook
p = iplot.InteractiveAllclose(cl, tsne_obj, objects, spd)
# Out:
# <img src="data:image/png;base64,..." width="1500">
